# %%
# 使用cv2将视频中人脸识别出来，并进行保存人脸
import numpy as np

import cv2

# %%
video = cv2.VideoCapture('../law.mp4')

fps = video.get(cv2.CAP_PROP_FPS)
face_detector = cv2.CascadeClassifier('../haarcascade_frontalface_alt.xml')

success, frame = video.read()
num = 0
while(success):
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    face_zones = face_detector.detectMultiScale(gray,1.2, 4, minSize=(80, 80))
    
    for x,y,w,h in face_zones:
        cv2.rectangle(frame, pt1=(x, y), pt2=(x+w, y+h), color=[0,0,255], thickness=2)
        np.random.rand()
        cv2.imwrite('./image/' + str(num) + '.jpg', frame[y: y+h, x: x+w])
        num += 1
    
    cv2.imshow('law', frame)
    
    if cv2.waitKey(int(1000//fps)) == ord('q'):
        break
        
    success, frame = video.read()
    
video.release()
cv2.destroyAllWindows()

# %%
import matplotlib.pyplot as plt
# 魔法指令， inline嵌入, 显示一次就显示出来
# %matplotlib inline

plt.imshow(frame)
